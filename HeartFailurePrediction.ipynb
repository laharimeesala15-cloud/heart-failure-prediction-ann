# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('/content/Cardiovascular_Disease_Dataset.csv')
df.drop(columns=['patientid'], inplace=True)
print(df.shape)
df.head()
# Out:
# (1000, 13)
#    age  gender  chestpain  restingBP  serumcholestrol  fastingbloodsugar  \
# 0   53       1          2        171                0                  0
# 1   40       1          0         94              229                  0
# 2   49       1          2        133              142                  0
# 3   43       1          0        138              295                  1
# 4   31       1          1        199                0                  0
#
#    restingrelectro  maxheartrate  exerciseangia  oldpeak  slope  \
# 0                1           147              0      5.3      3
# 1                1           115              0      3.7      1
# 2                0           202              1      5.0      1
# 3                1           153              0      3.2      2
# 4                2           136              0      5.3      3
#
#    noofmajorvessels  target
# 0                 3       1
# 1                 1       0
# 2                 0       0
# 3                 2       1
# 4                 2       1

# %%
print(df.columns.tolist())
# Out:
# ['age', 'gender', 'chestpain', 'restingBP', 'serumcholestrol', 'fastingbloodsugar', 'restingrelectro', 'maxheartrate', 'exerciseangia', 'oldpeak', 'slope', 'noofmajorvessels', 'target']

# %%
df.head()
# Out:
#    age  gender  chestpain  restingBP  serumcholestrol  fastingbloodsugar  \
# 0   53       1          2        171                0                  0
# 1   40       1          0         94              229                  0
# 2   49       1          2        133              142                  0
# 3   43       1          0        138              295                  1
# 4   31       1          1        199                0                  0
#
#    restingrelectro  maxheartrate  exerciseangia  oldpeak  slope  \
# 0                1           147              0      5.3      3
# 1                1           115              0      3.7      1
# 2                0           202              1      5.0      1
# 3                1           153              0      3.2      2
# 4                2           136              0      5.3      3
#
#    noofmajorvessels  target
# 0                 3       1
# 1                 1       0
# 2                 0       0
# 3                 2       1
# 4                 2       1

# %%
print(df.isnull().sum())
# Out:
# age                  0
# gender               0
# chestpain            0
# restingBP            0
# serumcholestrol      0
# fastingbloodsugar    0
# restingrelectro      0
# maxheartrate         0
# exerciseangia        0
# oldpeak              0
# slope                0
# noofmajorvessels     0
# target               0
# dtype: int64

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(df.corr(), annot=True, fmt='.2f', cmap='coolwarm')
plt.title('Feature Correlation Heatmap')
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

X = df.drop(columns=['target'])
y = df['target']

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42, stratify=y)

print("Training samples:", X_train.shape[0])
print("Testing samples:", X_test.shape[0])
# Out:
# Training samples: 800
# Testing samples: 200

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

model = Sequential([
    Dense(64, activation='relu', input_shape=(12,)),
    Dropout(0.3),
    Dense(32, activation='relu'),
    Dropout(0.2),
    Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 64)             │           832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,945 (11.50 KB)
#  Trainable params: 2,945 (11.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(X_train, y_train,
                    epochs=100,
                    batch_size=16,
                    validation_split=0.1,
                    verbose=1)
# Out:
# Epoch 1/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.6792 - loss: 0.5808 - val_accuracy: 0.9000 - val_loss: 0.4446
# Epoch 2/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8736 - loss: 0.3883 - val_accuracy: 0.9625 - val_loss: 0.2660
# Epoch 3/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9153 - loss: 0.2672 - val_accuracy: 0.9375 - val_loss: 0.1838
# Epoch 4/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9292 - loss: 0.2111 - val_accuracy: 0.9375 - val_loss: 0.1529
# Epoch 5/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9431 - loss: 0.1736 - val_accuracy: 0.9750 - val_loss: 0.1312
# Epoch 6/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9375 - loss: 0.1616 - val_accuracy: 0.9625 - val_loss: 0.1203
# Epoch 7/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9486 - loss: 0.1391 - val_accuracy: 0.9500 - val_loss: 0.1130
# Epoch 8/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.
100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9917 - loss: 0.0209 - val_accuracy: 0.9750 - val_loss: 0.0482
# Epoch 80/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9903 - loss: 0.0234 - val_accuracy: 0.9625 - val_loss: 0.0606
# Epoch 81/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9917 - loss: 0.0287 - val_accuracy: 0.9500 - val_loss: 0.0594
# Epoch 82/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9944 - loss: 0.0174 - val_accuracy: 0.9625 - val_loss: 0.0600
# Epoch 83/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9903 - loss: 0.0243 - val_accuracy: 0.9625 - val_loss: 0.0502
# Epoch 84/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9917 - loss: 0.0242 - val_accuracy: 0.9500 - val_loss: 0.0643
# Epoch 85/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9903 - loss: 0.0194 - val_accuracy: 0.9500 - val_loss: 0.0614
# Epoch 86/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9903 - loss: 0.0225 - val_accuracy: 0.9750 - val_loss: 0.0546
# Epoch 87/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9861 - loss: 0.0267 - val_accuracy: 0.9750 - val_loss: 0.0633
# Epoch 88/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9958 - loss: 0.0184 - val_accuracy: 0.9750 - val_loss: 0.0689
# Epoch 89/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9861 - loss: 0.0379 - val_accuracy: 0.9750 - val_loss: 0.0689
# Epoch 90/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9903 - loss: 0.0229 - val_accuracy: 0.9750 - val_loss: 0.0608
# Epoch 91/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9875 - loss: 0.0281 - val_accuracy: 0.9750 - val_loss: 0.0601
# Epoch 92/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9944 - loss: 0.0214 - val_accuracy: 0.9750 - val_loss: 0.0575
# Epoch 93/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9958 - loss: 0.0163 - val_accuracy: 0.9500 - val_loss: 0.0620
# Epoch 94/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9958 - loss: 0.0150 - val_accuracy: 0.9500 - val_loss: 0.0580
# Epoch 95/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9958 - loss: 0.0166 - val_accuracy: 0.9500 - val_loss: 0.0613
# Epoch 96/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9958 - loss: 0.0162 - val_accuracy: 0.9500 - val_loss: 0.0642
# Epoch 97/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9958 - loss: 0.0168 - val_accuracy: 0.9750 - val_loss: 0.0681
# Epoch 98/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9917 - loss: 0.0145 - val_accuracy: 0.9625 - val_loss: 0.0654
# Epoch 99/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9931 - loss: 0.0268 - val_accuracy: 0.9625 - val_loss: 0.0597
# Epoch 100/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9958 - loss: 0.0178 - val_accuracy: 0.9625 - val_loss: 0.0617

# %%
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import classification_report, confusion_matrix

y_pred = (model.predict(X_test) > 0.5).astype(int)

print(classification_report(y_test, y_pred))

plt.figure(figsize=(6, 4))
sns.heatmap(confusion_matrix(y_test, y_pred),
            annot=True, fmt='d', cmap='Blues',
            xticklabels=['No Disease', 'Disease'],
            yticklabels=['No Disease', 'Disease'])
plt.title('Confusion Matrix')
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.98        84
#            1       0.98      0.99      0.99       116
#
#     accuracy                           0.98       200
#    macro avg       0.99      0.98      0.98       200
# weighted avg       0.99      0.98      0.98       200

# %%
import numpy as np

# [age, gender, chestpain, restingBP, serumcholestrol, fastingbloodsugar,
#  restingrelectro, maxheartrate, exerciseangia, oldpeak, slope, noofmajorvessels]

new_patient = np.array([[52, 1, 2, 140, 230, 0, 1, 150, 0, 1.5, 1, 0]])

new_scaled = scaler.transform(new_patient)
prob = model.predict(new_scaled)[0][0]

print(f"Heart Disease Probability: {prob:.2%}")
print(f"Prediction: {'⚠️ HIGH RISK' if prob > 0.5 else '✅ LOW RISK'}")
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# Heart Disease Probability: 12.45%
# Prediction: ✅ LOW RISK
